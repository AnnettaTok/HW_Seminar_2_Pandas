# %% [markdown]
# #### 2.1. Начало работы
# 1. Скачать данные из файла kc_house_data.csv (прикреплен к семинару)
# 2. Считать данные с помощью pandas
# 3. Вывести на экран первые 5 строк
# 3. Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd

# %%
df = pd.read_csv('./kc_house_data.csv',encoding='cp1251') # Считать данные с помощью pandas

# %%
df.head(5) # Вывести на экран первые 5 строк
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.info() # Посмотреть на описание признаков и на их содержание
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %% [markdown]
# #### 2.2. Первичный анализ данных
# 1. Проведите первичный анализ данных
# 2. Изучите типы данных
# 3. Найдите количество пропущенных ячеек в данных
# 4. Посчитайте основные статистики по всем признакам и поизучайте их

# %%
df.info() # Проведите первичный анализ данных
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.dtypes # Изучите типы данных
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
df.isnull().sum().sum () #  количество пропущенных ячеек в данных
# Out:
# 0

# %%
df.describe() # Посчитайте основные статистики по всем признакам и поизучайте их
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.describe (include='all') # Посчитайте основные статистики по всем признакам и поизучайте их
# Out:
#                   id             date         price      bedrooms  \
# count   2.161300e+04            21613  2.161300e+04  21613.000000
# unique           NaN              372           NaN           NaN
# top              NaN  20140623T000000           NaN           NaN
# freq             NaN              142           NaN           NaN
# mean    4.580302e+09              NaN  5.400881e+05      3.370842
# std     2.876566e+09              NaN  3.671272e+05      0.930062
# min     1.000102e+06              NaN  7.500000e+04      0.000000
# 25%     2.123049e+09              NaN  3.219500e+05      3.000000
# 50%     3.904930e+09              NaN  4.500000e+05      3.000000
# 75%     7.308900e+09              NaN  6.450000e+05      4.000000
# max     9.900000e+09              NaN  7.700000e+06     33.000000
#
#            bathrooms   sqft_living      sqft_lot        floors    waterfront  \
# count   21613.000000  21613.000000  2.161300e+04  21613.000000  21613.000000
# ...

# %%
df.describe(include=['object']) # Посчитайте основные статистики по всем признакам и поизучайте их
# Out:
#                    date
# count             21613
# unique              372
# top     20140623T000000
# freq                142

# %% [markdown]
# #### 2.3.  Анализ рынка недвижимостис
# Ответьте на несколько вопросов:
# 1 В каком диапазоне изменяются стоимости недвижимости?
# 2 Какую долю в среднем занимают жилая площадь от всей площади по всем домам?
# 3 Как много домов с разными этажами в данных?
# 4 Насколько хорошие состояния у домов в данных?
# 5 Найдите года, когда построили первый дом, когда построили последний дом в данных?

# %%
df.head(2)
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
#
#    sqft_lot15
# 0        5650
# 1        7639
#
# [2 rows x 21 columns]

# %%
df["price"] # все цены
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
df["price"].min() # минимальная стоимость
# Out:
# 75000.0

# %%
df["price"].max() # максимальная стоимость
# Out:
# 7700000.0

# %%
df["sqft_living"].mean() # среднее значение жилой площади
# Out:
# 2079.8997362698374

# %%
df["sqft_lot"].mean() # среднее значение общей площади
# Out:
# 15106.967565816869

# %%
livingMean = df["sqft_living"].mean()
lotMean = df["sqft_lot"].mean()
livingMean/lotMean*100 # доля в процентах жилой площади от всей площади по всем домам
# Out:
# 13.76781757959227

# %%
df["floors"].value_counts() # домa с разными этажами в данных
# Out:
# floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64

# %%
df["condition"].value_counts() # Насколько хорошие состояния у домов в данных
# Out:
# condition
# 3    14031
# 4     5679
# 5     1701
# 2      172
# 1       30
# Name: count, dtype: int64

# %%
df["yr_built"].min() # дата постройки первого дома
# Out:
# 1900

# %%
df["yr_built"].max() # Дата постройки последнего дома
# Out:
# 2015

# %% [markdown]
# #### 2.4.  Анализ рынка недвижимости - 2
# 1. Сколько в среднем стоят дома, у которых 2 спальни?
# 2. Какая в среднем общая площадь домов(sqft_lot), у которых стоимость больше 600000?
# 3. Как много домов коснулся ремонт? Как много домов не было отремонтировано? Используйте поле yr_renovated. Подсчитайте процентное отношение этих величин.
# 4. Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4

# %%
df["bedrooms"] == 2
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610     True
# 21611    False
# 21612     True
# Name: bedrooms, Length: 21613, dtype: bool

# %%
df[df["bedrooms"] == 2]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 11     9212900260  20140527T000000  468000.0         2       1.00
# 18       16000397  20141205T000000  189000.0         2       1.00
# 23     8091400200  20140516T000000  252700.0         2       1.50
# 31     2426039314  20141201T000000  280000.0         2       1.50
# ...           ...              ...       ...       ...        ...
# 21586  2767604724  20141015T000000  505000.0         2       2.50
# 21588  2767600688  20141113T000000  414500.0         2       1.50
# 21595  1972201967  20141031T000000  520000.0         2       2.25
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 2              770     10000     1.0           0     0  ...      6
# ...

# %%
df[df["bedrooms"] == 2].describe() # 4.013727e+05 на пересечение mean и price - Столько в среднем стоят дома, у которых 2 спальни
# Out:
#                  id         price  bedrooms    bathrooms  sqft_living  \
# count  2.760000e+03  2.760000e+03    2760.0  2760.000000  2760.000000
# mean   4.636499e+09  4.013727e+05       2.0     1.401721  1239.752899
# std    2.892332e+09  1.980518e+05       0.0     0.540169   463.876000
# min    7.200179e+06  7.800000e+04       2.0     0.500000   440.000000
# 25%    2.155375e+09  2.698375e+05       2.0     1.000000   910.000000
# 50%    3.904100e+09  3.740000e+05       2.0     1.000000  1140.000000
# 75%    7.452500e+09  4.900000e+05       2.0     1.750000  1440.000000
# max    9.895000e+09  3.278000e+06       2.0     3.500000  6840.000000
#
#            sqft_lot       floors   waterfront         view    condition  \
# count  2.760000e+03  2760.000000  2760.000000  2760.000000  2760.000000
# mean   1.209673e+04     1.306703     0.011232     0.178623     3.377899
# std    4.773959e+04     0.538017     0.105403     0.677109     0.665750
# ...

# %%
df[df["bedrooms"] == 2]['price'].mean() # Столько в среднем стоят дома, у которых 2 спальни
# Out:
# 401372.681884058

# %% [markdown]
# 2. Какая в среднем общая площадь домов(sqft_lot), у которых стоимость больше 600000?

# %%
df[df["price"] >= 6000000]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 3914        10040     37325     2.0           1     2  ...     11        7680
# 7252        12050     27600     2.5           0     3  ...     13        8570
# 9254         9890     31374     2.0           0     4  ...     13        8860
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 3914           2360      1940          2001    98004  47.6500 -122.214
# 7252           3480      1910          1987    98102  47.6298 -122.323
# 9254           1030      2001             0    98039  47.6305 -122.240
#
#       sqft_living15  sqft_lot15
# 3914           3930       25449
# ...

# %%
df[df["price"] >= 6000000]['sqft_lot'].mean()
# Out:
# 32099.666666666668

# %% [markdown]
# 3. Как много домов коснулся ремонт? Как много домов не было отремонтировано? Используйте поле yr_renovated. Подсчитайте процентное отношение этих величин.

# %%
df[df["yr_renovated"] == 0] # Не отремонтированные дома
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# ...           ...              ...        ...       ...        ...
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
df[df["yr_renovated"] > 0] # отремонтированные дома
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 35     9547205180  20140613T000000   696000.0         3       2.50
# 95     1483300570  20140908T000000   905000.0         4       2.50
# 103    2450000295  20141007T000000  1088000.0         3       2.50
# 115    3626039325  20141121T000000   740500.0         3       3.50
# ...           ...              ...        ...       ...        ...
# 19622  7351200295  20150114T000000  1150000.0         3       1.75
# 20057   126039256  20140904T000000   434900.0         3       2.00
# 20444  4305600360  20150225T000000   500012.0         4       2.50
# 20447  3319500628  20150212T000000   356999.0         3       1.50
# 20962  1278000210  20150311T000000   110000.0         2       1.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1             2570      7242     2.0           0     0  ...      7
# ...

# %%
df[df["yr_renovated"] > 0].shape[0] #  кол-во отремонтированных домов
# Out:
# 914

# %%
df[df["yr_renovated"] == 0].shape[0] # кол-во не отремонтированных
# Out:
# 20699

# %%
df[df["yr_renovated"] > 0].shape[0]/df[df["yr_renovated"] == 0].shape[0]*100 # процентное соотношение
# Out:
# 4.415672254698295

# %% [markdown]
# 4. Насколько в среднем стоимость домов с оценкой grade домов выше 10 отличается от стоимости домов с оценкой grade меньше 4

# %%
df[df["grade"] > 10] # дома с оценкой выше 10
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 269    7960900060  20150504T000000  2900000.0         4       3.25
# 270    4054500390  20141007T000000  1365000.0         4       4.75
# ...           ...              ...        ...       ...        ...
# 21532   324069112  20140617T000000  1325000.0         4       4.00
# 21548  8835770330  20140819T000000  1057000.0         2       1.50
# 21551  1561750040  20141224T000000  1375000.0         5       4.50
# 21590  7430200100  20140514T000000  1222500.0         4       3.50
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %%
df[df["grade"] < 4 ] # дома с оценкой ниже 4
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 1149   3421079032  20150217T000000   75000.0         1       0.00
# 3223   2420069251  20150225T000000  262000.0         1       0.75
# 5832   5702500050  20141104T000000  280000.0         1       0.00
# 19452  3980300371  20140926T000000  142000.0         0       0.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 1149           670     43377     1.0           0     0  ...      3
# 3223           520     12981     1.0           0     0  ...      3
# 5832           600     24501     1.0           0     0  ...      3
# 19452          290     20875     1.0           0     0  ...      1
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 1149          670              0      1966             0    98022  47.2638
# 3223          520              0      1920             0    98022  47.2082
# ...

# %%
df[df["grade"] > 10]['price'].mean() # средняя стоимость домов с оценкой больше 10
# Out:
# 1678635.1175298805

# %%
df[df["grade"] < 4]['price'].mean() # средняя стоимость домов с оценкой меньше 4
# Out:
# 189750.0

# %%
df[df["grade"] > 10]['price'].mean()-df[df["grade"] < 4]['price'].mean() # разница
# Out:
# 1488885.1175298805

# %% [markdown]
# #### 2.5.  Работа с клиентом
# 1 Выберите дом клиенту. Клиент хочет дом с видом на набережную(waterfront), как минимум с тремя ванными и с подвалом.
#     - Сколько вариантов есть у клиента?
#     - Выведите все варианты таблицей
# 2 Выберите дом клиенту.
# Клиент хочет дом
#     - либо с очень красивым видом(параметр 'view' - больше) из окна, либо с видом на набережную(waterfront)
#     - и в очень хорошем состоянии(condition) и год постройки не меньше 1980 года.
#     - В какой ценовом диапазоне будут дома?
# 3 Выберите дом клиенту. Клиент хочет дом
#     - без подвала
#     - с двумя этажами
#     - стоимостью до 150000.
#     - Какая оценка по состоянию у таких домов в среднем?

# %%
df[(df["waterfront"] > 0) & (df["bathrooms"] >= 3) & (df["sqft_basement"] > 0)].shape[0] # общее кол-во вариантов
# Out:
# 41

# %%
df[(df["waterfront"] > 0) & (df["bathrooms"] >= 3) & (df["sqft_basement"] > 0)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 300    3225069065  20140624T000000  3075000.0         4       5.00
# 457    2122039094  20141126T000000   705000.0         3       3.00
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1261   7636800041  20140625T000000   995000.0         3       4.50
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1361   1925069082  20150511T000000  2200000.0         5       4.25
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2864   4114601570  20141118T000000  3600000.0         3       3.25
# 3914   9808700762  20140611T000000  7062500.0         5       4.50
# 3934   1269200229  20140723T000000  1379900.0         3       3.25
# 5760    623059016  20140717T000000  1100000.0         4       3.25
# 6233   2024069008  20140619T000000  2200000.0         5       4.75
# 6508   4217402115  20150421T000000  3650000.0         6       4.75
# ...

# %% [markdown]
# Клиент хочет дом
#     - либо с очень красивым видом(параметр 'view' - больше) из окна, либо с видом на набережную(waterfront)
#     - и в очень хорошем состоянии(condition) и год постройки не меньше 1980 года.
#     - В какой ценовом диапазоне будут дома?

# %%
df[(df["view"] > 0 ) | (df["waterfront"] > 0 )] # Первое условие
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 15     9297300055  20150124T000000   650000.0         4       3.00
# 21     2524049179  20140826T000000  2000000.0         3       2.75
# 49      822039084  20150311T000000  1350000.0         3       2.50
# 58     7922800400  20140827T000000   951000.0         5       3.25
# 60     1516000055  20141210T000000   650000.0         3       2.25
# ...           ...              ...        ...       ...        ...
# 21554  2855000110  20140808T000000   388000.0         3       2.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21579  7011201004  20140529T000000   645000.0         3       3.25
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21598  8956200760  20141013T000000   541800.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 15            2950      5000     2.0           0     3  ...      9
# ...

# %%
df[(df["condition"] > 0 ) & (df["yr_built"] >= 1980) ] # Второе условие
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 16     1875500060  20140731T000000   395000.0         3       2.00
# ...           ...              ...        ...       ...        ...
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 4             1680      8080     1.0           0     0  ...      8
# ...

# %%
df[((df["view"] > 0 ) | (df["waterfront"] > 0 )) & (df["condition"] > 0 ) & (df["yr_built"] >= 1980) ] # для корректной работы необходимо первое условие с ИЛи поставить в доп скобки ()
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 99     7338200240  20140516T000000   437500.0         3       2.50
# 114    8961960160  20141028T000000   480000.0         4       2.50
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 185     825059270  20141121T000000  1095000.0         5       3.00
# 246    2025069065  20140929T000000  2400000.0         4       2.50
# ...           ...              ...        ...       ...        ...
# 21554  2855000110  20140808T000000   388000.0         3       2.50
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21579  7011201004  20140529T000000   645000.0         3       3.25
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21598  8956200760  20141013T000000   541800.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 99            2320     36847     2.0           0     2  ...      9
# ...

# %%
df[['view','waterfront', 'condition','yr_built']] # Выводит тоько нужные столбцы
# Out:
#        view  waterfront  condition  yr_built
# 0         0           0          3      1955
# 1         0           0          3      1951
# 2         0           0          3      1933
# 3         0           0          5      1965
# 4         0           0          3      1987
# ...     ...         ...        ...       ...
# 21608     0           0          3      2009
# 21609     0           0          3      2014
# 21610     0           0          3      2009
# 21611     0           0          3      2004
# 21612     0           0          3      2008
#
# [21613 rows x 4 columns]

# %% [markdown]
# 3 Выберите дом клиенту. Клиент хочет дом
#     - без подвала
#     - с двумя этажами
#     - стоимостью до 150000.
#     - Какая оценка по состоянию у таких домов в среднем?

# %%
df[(df["sqft_basement"] == 0) & (df["floors"] == 2) & (df["price"]  <= 150000)]["condition"].mean()
# Out:
# 3.0
